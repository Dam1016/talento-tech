# %%
mi_lista=[1,2,3,4,8,"Victor",4.5]
print(mi_lista)
campista=["pepito","perez",20,4.5,"calle 4"]
print(campista[1])
print(campista[0:3])
print("la direccion del campista es:",campista[4])
print(campista[-1])

print(len(campista))
campista.append("medico")
print(campista)
celular=int(input("cuel es tu numero de celular: "))
campista.append(celular)
print(campista)
barrio=input("cual es tu barrio: ")
campista.insert(5,barrio)
print(campista)
# Out:
# [1, 2, 3, 4, 8, 'Victor', 4.5]
# perez
# ['pepito', 'perez', 20]
# la direccion del campista es: calle 4
# calle 4
# 5
# ['pepito', 'perez', 20, 4.5, 'calle 4', 'medico']

# %%
mi_tupla=(1,2,3,"pedro",3.4)
print(mi_tupla[3])
print(mi_tupla[1:4])
print(mi_tupla[-2])
print(len(mi_tupla))
