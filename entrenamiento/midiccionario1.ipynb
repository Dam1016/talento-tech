# %%
mi_diccionario={"hola":"hello","adios":"bye"}
print(mi_diccionario["hola"])
mi_diccionario["rojo"]="red"
print(mi_diccionario)
mi_diccionario["rojo"]="blue"
print(mi_diccionario)

campistas={"victor":{"edad":30,"celular":3166249127,"direccion":"carrera 5"},"maria":{"edad":25,"celular":3216548574,"direccion":"calle 20"}}
print(campistas)

paises=("españa","italia","alemania")
capitales={paises[0]:"madrid",paises[1]:"roma",paises[2]:"berlin"}
print(capitales)

del capitales [paises[0]]
print(capitales)

print(campistas.get("ana","este campista no existe"))
print(campistas.keys())
print(campistas.values())
print(len(campistas))
campistas.clear
print(campistas)
# Out:
# hello
# {'hola': 'hello', 'adios': 'bye', 'rojo': 'red'}
# {'hola': 'hello', 'adios': 'bye', 'rojo': 'blue'}
# {'victor': {'edad': 30, 'celular': 3166249127, 'direccion': 'carrera 5'}, 'maria': {'edad': 25, 'celular': 3216548574, 'direccion': 'calle 20'}}
# {'españa': 'madrid', 'italia': 'roma', 'alemania': 'berlin'}
# {'italia': 'roma', 'alemania': 'berlin'}
# este campista no existe
# dict_keys(['victor', 'maria'])
# dict_values([{'edad': 30, 'celular': 3166249127, 'direccion': 'carrera 5'}, {'edad': 25, 'celular': 3216548574, 'direccion': 'calle 20'}])
# 2
# {'victor': {'edad': 30, 'celular': 3166249127, 'direccion': 'carrera 5'}, 'maria': {'edad': 25, 'celular': 3216548574, 'direccion': 'calle 20'}}
