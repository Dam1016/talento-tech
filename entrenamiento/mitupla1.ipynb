# %%
mi_tupla=(1,2,3,"pedro",3.4,3,3)
print(mi_tupla[3])
print(mi_tupla[1:4])
print(mi_tupla[-2])
print(len(mi_tupla))
print(3.4 in mi_tupla)
print(mi_tupla.index(3.4))
print(mi_tupla.count(2))
mi_lista=list(mi_tupla)
mi_lista.insert(4,"perez")
mi_tupla=tuple(mi_lista)
print(mi_tupla)
campistas=("carlos","gomez",30,3166249127,4.4)
nombre,apellido,edad,celular,nota=campistas
print(celular)
print(apellido)
# Out:
# pedro
# (2, 3, 'pedro')
# 3
# 7
# True
# 4
# 1
# (1, 2, 3, 'pedro', 'perez', 3.4, 3, 3)
# 3166249127
# gomez
